# %% [markdown]
# # Julia Things

# %% [markdown]
# ### Environment
#
# First things first. Let us set up the environment with the requried packages for this notebook:

# %%
for p in ("Knet", "Plots", "Plotly.jl")
    Pkg.installed(p) == nothing && Pkg.add(p)
end

using Knet, Plots
gr()

Knet.gpu(0); # set the desired GPU to use
atype = KnetArray{Float32}; # atype = KnetArray{Float32} for gpu usage, Array{Float32} for cpu. 

println("OS: ", Sys.KERNEL)
println("Julia: ", VERSION)
println("Knet: ", Pkg.installed("Knet"))
println("GPU: ", readstring(`nvidia-smi --query-gpu=name --format=csv,noheader`))
# Out:
# OS: Linux
# Julia: 0.6.0
# Knet: 0.8.5+
# GPU: NVS 310
# TITAN X (Pascal)

# %% [markdown]
# ### New Stuff
#
# In this notebook we introduce the following Julia/Knet packages and functions:
#
# * ...

# %% [markdown]
# # Generative Adversarial Networks (GANs)
#
# Many of the applications are in the context of images. Since this takes too much time to solve in a Jupyter notebook on a laptop, we're going to provide a simpler example by fitting a much simpler distribution. We will illustrate what happens if we use GANs to build the world's most inefficient estimator of parameters for a Gaussian. Let's get started. Since this is going to be the world's lamest example, we simply generate data drawn from a Gaussian. And let's also set a context where we'll do most of the computation.

# %%
xtrn = randn(2, 1000);
ytrn = ones(UInt8, 1, 1000);
w    = [[1 2; -0.1 0.5]', [1, 2]];
xtrn = w[1] * xtrn .+ w[2];

# %%
batch_size = 4;
dtrn = minibatch(xtrn, ytrn, batch_size, xtype=atype, shuffle=true);

# %% [markdown]
# Let's see what we got. This should be a Gaussian shifted in some rather arbitrary way with mean $b$ and covariance matrix $A^\top A$.

# %%
print("The covariance matrix is:\n")
A = w[1]'
A * A'
# Out:
# The covariance matrix is:
# 2×2 Array{Float64,2}:
#  5.0  0.9
#  0.9  0.26

# %%
scatter(xtrn[1, :], xtrn[2, :], legend=false)
xticks!([-2, 1, 4]); yticks!([-4, 2, 8])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.2878,370.353 73.2878,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   319.671,370.353 319.671,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   566.054,370.353 566.054,17.2711
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,353.872 572.049,353.872
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,195.416 572.049,195.416
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,36.9601 572.049,36.9601
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   73.2878,375.813 73.2878,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   319.671,375.813 319.671,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   566.054,375.813 566.054,370.353
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,353.872 37.525,353.872
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,195.416 37.525,195.416
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,36.9601 37.525,36.9601
#   "/>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 73.2878, 389.613)" x="73.2878" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 319.671, 389.613)" x="319.671" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 566.054, 389.613)" x="566.054" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 358.372)" x="23.2591" y="358.372">-4</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 199.916)" x="23.2591" y="199.916">2</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 41.4601)" x="23.2591" y="41.4601">8</text>
# </g>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="281.014" cy="196.043" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="281.014" cy="196.043" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="310.495" cy="211.669" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="310.495" cy="211.669" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="461.348" cy="98.1287" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="461.348" cy="98.1287" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="335.431" cy="205.013" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="335.431" cy="205.013" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="338.541" cy="200.772" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="338.541" cy="200.772" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="255.454" cy="233.097" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="255.454" cy="233.097" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="331.562" cy="175.963" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="331.562" cy="175.963" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="166.345" cy="326.072" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="166.345" cy="326.072" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="330.072" cy="185.524" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="330.072" cy="185.524" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="317.896" cy="197.669" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="317.896" cy="197.669" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="292.793" cy="205.891" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="292.793" cy="205.891" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="282.841" cy="223.918" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="282.841" cy="223.918" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="304.441" cy="182.737" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="304.441" cy="182.737" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="303.017" cy="234.013" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="303.017" cy="234.013" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; stroke:none; fill-opacity:1" cx="346.321" cy="193.148" r="4"/>
# <circle clip-path="url(#clip5202)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="346.321" cy="193.148" r="3"/>
# <circle clip-path="url(#clip5202)" style="fill:#000000; strok

# %% [markdown]
# ## Define the networks
#
# Next we need to define how to fake data. Our generator network will be the simplest network possible - a single layer linear model. This is since we'll be driving that linear network with a Gaussian data generator. Hence, it literally only needs to learn the parameters to fake things perfectly. For the discriminator we will be a bit more discriminating: we will use an MLP with 3 layers to make things a bit more interesting.
#
# The cool thing here is that we have *two* different networks, each of them with their own gradients, optimizers, losses, etc. that we can optimize as we please.

# %% [markdown]
# The function `initweights` allows to initialize a model of arbitrary depth, assuming that the parameters of each layer consist of an $H\times X$ matrix and a vector of size $H$. We can define the shape of the matrices with the keyword argument `hidden`, a vector with the matrix sizes. We can also define the dimension of the input layer with the variable $d$ such that $x_i\in\mathbb{R}^d$ for $i=1,\dots,N$, where $N$ is the number of samples. For example, if we want a single densely connect layer with `xtrn` as input, we can simply call `initweights(2)` since by default `initweights` initializes a single layer with output size `1`. Using `initweights` we can define but the generator and discriminator units:

# %%
function initweights(d, hidden)
    model = Vector{Any}(2 * length(hidden))
    X = d
    for k = 1:length(hidden)
        H = hidden[k]
        model[2k - 1] = randn(H, X)
        model[2k]     = zeros(H, 1)
        X = H
    end
    return model
end
# Out:
# initweights (generic function with 1 method)

# %%
generator_init(d, atype)     = map(atype, initweights(d, [2]));
discriminator_init(d, atype) = map(atype, initweights(d, [5, 3, 2]));

# %% [markdown]
# We can also create a single `predict` function for both models:

# %%
function predict(w, x)
    x = mat(x)
    for i=1:2:length(w) - 2
        x = tanh.(w[i] * x .+ w[i+1])
    end
    return w[end - 1]*x .+ w[end]
end
# Out:
# predict (generic function with 1 method)

# %%
loss(w, x, y) = nll(predict(w, x), y)
lossgradient  = grad(loss)
# Out:
# (::gradfun) (generic function with 1 method)

# %%
function train(w, x, y, optim)
    
    g = lossgradient(w, x, y)
    update!(w, g, optim)
    
    return w
    
end
# Out:
# train (generic function with 1 method)

# %%
wg = generator_init(2, atype);
wd = discriminator_init(2, atype);

optimg = optimizers(wg, Adam;  lr=0.01)
optimd = optimizers(wd, Adam;  lr=0.05)

Fake_x = []
for epoch = 1:10
    
    push!(Fake_x, predict(wg, atype(randn(2, 100))));
    for (x, y) in dtrn
        
        # generate fake inputs from noise
        noise  = atype(randn(size(x)))
        fake_x = copy(predict(wg, noise));
        fake_y = Array{UInt8}(2ones(size(y)))
        
        x_ = hcat(x, fake_x)
        y_ = hcat(y, fake_y)
        
        wd     = train(wd, x_, y_, optimd)  
        output = predict(wd, fake_x)
        wg     = train(wg, output, y, optimg)
    end  
    
    if epoch % 2 == 0
        scatter(xtrn[1, :], xtrn[2, :], label=:true_data)
        xpred = Array(Fake_x[epoch])
        display(scatter!(xpred[1, :], xpred[2, :],  label=:synthetic_data, size=(400,300)))
    end
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="400" height="300" viewBox="0 0 400 300">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="400" height="300"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6400)" points="
# 0,300 400,300 400,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="80" y="0" width="281" height="281"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6400)" points="
# 39.1436,274.759 380.315,274.759 380.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="11" width="342" height="264"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   66.4027,270.814 66.4027,15.7552
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   117.25,270.814 117.25,15.7552
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   168.097,270.814 168.097,15.7552
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   218.944,270.814 218.944,15.7552
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   269.791,270.814 269.791,15.7552
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   320.638,270.814 320.638,15.7552
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.486,270.814 371.486,15.7552
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,230.293 375.197,230.293
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,182.599 375.197,182.599
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,134.905 375.197,134.905
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,87.2109 375.197,87.2109
#   "/>
# <polyline clip-path="url(#clip6402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,39.517 375.197,39.517
#   "/>
# <polyline clip-path="url(#clip6400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,274.759 380.315,274.759
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,274.759 39.1436,11.811
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.4027,274.759 66.4027,270.814
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   117.25,274.759 117.25,270.814
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   168.097,274.759 168.097,270.814
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   218.944,274.759 218.944,270.814
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   269.791,274.759 269.791,270.814
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   320.638,274.759 320.638,270.814
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.486,274.759 371.486,270.814
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,230.293 44.2612,230.293
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,182.599 44.2612,182.599
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,134.905 44.2612,134.905
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,87.2109 44.2612,87.2109
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,39.517 44.2612,39.517
#   "/>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 66.4027, 287.559)" x="66.4027" y="287.559">-2</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 117.25, 287.559)" x="117.25" y="287.559">-1</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 168.097, 287.559)" x="168.097" y="287.559">0</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 218.944, 287.559)" x="218.944" y="287.559">1</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.791, 287.559)" x="269.791" y="287.559">2</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 320.638, 287.559)" x="320.638" y="287.559">3</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 371.486, 287.559)" x="371.486" y="287.559">4</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 234.793)" x="35.1436" y="234.793">-2.5</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 187.099)" x="35.1436" y="187.099">0.0</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 139.405)" x="35.1436" y="139.405">2.5</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 91.7109)" x="35.1436" y="91.7109">5.0</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 44.017)" x="35.1436" y="44.017">7.5</text>
# </g>
# <circle clip-path="url(#clip6602)" style="fill:#000000; stroke:none; fill-opacity:1" cx="195.011" cy="144.896" r="4"/>
# <circle clip-path="url(#clip6602)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="195.011" cy="144.896" r="3"/>
# <circle clip-path="url(#clip6602)" style="fill:#000000; str
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="400" height="300" viewBox="0 0 400 300">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="400" height="300"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6800)" points="
# 0,300 400,300 400,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="80" y="0" width="281" height="281"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6800)" points="
# 39.1436,274.759 380.315,274.759 380.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="11" width="342" height="264"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   71.1428,270.814 71.1428,15.7552
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   121.198,270.814 121.198,15.7552
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.253,270.814 171.253,15.7552
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   221.308,270.814 221.308,15.7552
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   271.363,270.814 271.363,15.7552
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   321.418,270.814 321.418,15.7552
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.473,270.814 371.473,15.7552
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,230.293 375.197,230.293
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,182.599 375.197,182.599
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,134.905 375.197,134.905
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,87.2109 375.197,87.2109
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,39.517 375.197,39.517
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,274.759 380.315,274.759
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,274.759 39.1436,11.811
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   71.1428,274.759 71.1428,270.814
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   121.198,274.759 121.198,270.814
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.253,274.759 171.253,270.814
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   221.308,274.759 221.308,270.814
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#
)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,39.517 375.197,39.517
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,274.759 380.315,274.759
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,274.759 39.1436,11.811
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.4027,274.759 66.4027,270.814
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   117.25,274.759 117.25,270.814
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   168.097,274.759 168.097,270.814
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   218.944,274.759 218.944,270.814
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   269.791,274.759 269.791,270.814
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   320.638,274.759 320.638,270.814
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.486,274.759 371.486,270.814
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,230.293 44.2612,230.293
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,182.599 44.2612,182.599
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,134.905 44.2612,134.905
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,87.2109 44.2612,87.2109
#   "/>
# <polyline clip-path="url(#clip7000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,39.517 44.2612,39.517
#   "/>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 66.4027, 287.559)" x="66.4027" y="287.559">-2</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 117.25, 287.559)" x="117.25" y="287.559">-1</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 168.097, 287.559)" x="168.097" y="287.559">0</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 218.944, 287.559)" x="218.944" y="287.559">1</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.791, 287.559)" x="269.791" y="287.559">2</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 320.638, 287.559)" x="320.638" y="287.559">3</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 371.486, 287.559)" x="371.486" y="287.559">4</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 234.793)" x="35.1436" y="234.793">-2.5</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 187.099)" x="35.1436" y="187.099">0.0</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 139.405)" x="35.1436" y="139.405">2.5</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 91.7109)" x="35.1436" y="91.7109">5.0</text>
# </g>
# <g clip-path="url(#clip7000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.1436, 44.017)" x="35.1436" y="44.017">7.5</text>
# </g>
# <circle clip-path="url(#clip7002)" style="fill:#000000; stroke:none; fill-opacity:1" cx="195.011" cy="144.896" r="4"/>
# <circle clip-path="url(#clip7002)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="195.011" cy="144.896" r="3"/>
# <circle clip-path="url(#clip7002)" style="fill:#000000; str
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="400" height="300" viewBox="0 0 400 300">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="400" height="300"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7200)" points="
# 0,300 400,300 400,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="80" y="0" width="281" height="281"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7200)" points="
# 39.1436,274.759 380.315,274.759 380.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="11" width="342" height="264"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   93.4585,270.814 93.4585,15.7552
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   184.56,270.814 184.56,15.7552
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   275.661,270.814 275.661,15.7552
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   366.763,270.814 366.763,15.7552
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,230.293 375.197,230.293
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44