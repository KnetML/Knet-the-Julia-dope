# %% [markdown]
# # Julia Things

# %% [markdown]
# ### Environment
#
# First things first. Let us set up the environment with the requried packages for this notebook:

# %%
for p in ("Knet", "Plots", "Plotly.jl")
    Pkg.installed(p) == nothing && Pkg.add(p)
end

using Knet, Plots
gr()

Knet.gpu(0); # set the desired GPU to use
atype = Array{Float32}; # atype = KnetArray{Float32} for gpu usage, Array{Float32} for cpu. 

println("OS: ", Sys.KERNEL)
println("Julia: ", VERSION)
println("Knet: ", Pkg.installed("Knet"))
println("GPU: ", readstring(`nvidia-smi --query-gpu=name --format=csv,noheader`))
# Out:
# OS: Linux
# Julia: 0.6.0
# Knet: 0.8.5+
# GPU: NVS 310
# TITAN X (Pascal)

# %% [markdown]
# ### New Stuff
#
# In this notebook we introduce the following Julia/Knet packages and functions:
#
# * ...

# %% [markdown]
# # Generative Adversarial Networks (GANs)
#
# Many of the applications are in the context of images. Since this takes too much time to solve in a Jupyter notebook on a laptop, we're going to provide a simpler example by fitting a much simpler distribution. We will illustrate what happens if we use GANs to build the world's most inefficient estimator of parameters for a Gaussian. Let's get started. Since this is going to be the world's lamest example, we simply generate data drawn from a Gaussian. And let's also set a context where we'll do most of the computation.

# %%
xtrn = randn(2, 1000);
ytrn = ones(UInt8, 1, 1000);
w    = [[1 2; -0.1 0.5]', [1, 2]];
xtrn = w[1] * xtrn .+ w[2];

# %%
batch_size = 4;
dtrn = minibatch(xtrn, ytrn, batch_size, xtype=atype, shuffle=true);

# %% [markdown]
# Let's see what we got. This should be a Gaussian shifted in some rather arbitrary way with mean $b$ and covariance matrix $A^\top A$.

# %%
print("The covariance matrix is:\n")
A = w[1]'
A * A'
# Out:
# The covariance matrix is:
# 2×2 Array{Float64,2}:
#  5.0  0.9
#  0.9  0.26

# %%
scatter(xtrn[1, :], xtrn[2, :], legend=false)
xticks!([-2, 1, 4]); yticks!([-4, 2, 8])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6900)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   78.3666,370.353 78.3666,17.2711
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   319.488,370.353 319.488,17.2711
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   560.609,370.353 560.609,17.2711
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,348.795 572.049,348.795
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,189.438 572.049,189.438
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.525,30.0798 572.049,30.0798
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   78.3666,375.813 78.3666,370.353
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   319.488,375.813 319.488,370.353
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   560.609,375.813 560.609,370.353
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,348.795 37.525,348.795
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,189.438 37.525,189.438
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,30.0798 37.525,30.0798
#   "/>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0,
" style="fill:#009af9; stroke:none; fill-opacity:1" cx="362.28" cy="142.727" r="3"/>
# <circle clip-path="url(#clip6902)" style="fill:#000000; stroke:none; fill-opacity:1" cx="299.299" cy="174.965" r="4"/>
# <circle clip-path="url(#clip6902)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="299.299" cy="174.965" r="3"/>
# <circle clip-path="url(#clip6902)" style="fill:#000000; stroke:none; fill-opacity:1" cx="276.718" cy="171.679" r="4"/>
# <circle clip-path="url(#clip6902)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="276.718" cy="171.679" r="3"/>
# <circle clip-path="url(#clip6902)" style="fill:#000000; stroke:none

# %% [markdown]
# ## Define the networks
#
# Next we need to define how to fake data. Our generator network will be the simplest network possible - a single layer linear model. This is since we'll be driving that linear network with a Gaussian data generator. Hence, it literally only needs to learn the parameters to fake things perfectly. For the discriminator we will be a bit more discriminating: we will use an MLP with 3 layers to make things a bit more interesting.
#
# The cool thing here is that we have *two* different networks, each of them with their own gradients, optimizers, losses, etc. that we can optimize as we please.

# %% [markdown]
# The function `initweights` allows to initialize a model of arbitrary depth, assuming that the parameters of each layer consist of an $H\times X$ matrix and a vector of size $H$. We can define the shape of the matrices with the keyword argument `hidden`, a vector with the matrix sizes. We can also define the dimension of the input layer with the variable $d$ such that $x_i\in\mathbb{R}^d$ for $i=1,\dots,N$, where $N$ is the number of samples. For example, if we want a single densely connect layer with `xtrn` as input, we can simply call `initweights(2)` since by default `initweights` initializes a single layer with output size `1`. Using `initweights` we can define but the generator and discriminator units:

# %%
function initweights(d; hidden=[2], atype=Array{Float32})
    winit(d...) = atype(xavier(Float32, d...))
    binit(d...) = atype(zeros(Float32, d...))
    
    model = Vector{Any}(2 * length(hidden))
    X = d
    for k = 1:length(hidden)
        H = hidden[k]
        model[2k - 1] = winit(H, X) 
        model[2k]     = binit(H, 1)
        X = H
    end
    return model
end
# Out:
# initweights (generic function with 1 method)

# %%
generator_init(d; atype=Array{Float32})     = initweights(d; atype=atype);
discriminator_init(d; atype=Array{Float32}) = initweights(d; hidden=[5, 3, 2], atype=atype);

# %% [markdown]
# We can also create a single `predict` function for both models:

# %%
function predict(w, x)
    x = mat(x)
    for i=1:2:length(w) - 2
        x = tanh.(w[i] * x .+ w[i+1])
    end
    return w[end - 1]*x .+ w[end]
end
# Out:
# predict (generic function with 1 method)

# %% [markdown]
# Let's make sure that this works as expected:

# %%
w  = generator_init(2)
x1 = w[1] * xtrn .+ w[2];
x1 == predict(w, xtrn)
# Out:
# true

# %%
w  = discriminator_init(2)
x1 = tanh.(w[1] * xtrn .+ w[2]);
x2 = tanh.(w[3] * x1 .+ w[4]);
x3 = w[5] * x2 .+ w[6];
x3 == predict(w, xtrn)
# Out:
# true

# %%
function loss(w, x, y)
    yhat = sigm.(predict(w, x))
    return - mean(y .* log.(yhat) + (1-y) .* log.(1-yhat))
end

lossgradient = grad(loss)
# Out:
# (::gradfun) (generic function with 1 method)

# %%
lossgradient(generator_init(2), xtrn , ytrn)
# Out:
# 2-element Array{Any,1}:
#  [-0.112095 -0.196758; -0.231777 -0.463464]
#  [-0.176371; -0.239895]

# %%
function traind(wd, wg, x, y, optimd)
    noise  = Array{Float32}(randn(size(x)))
    fake_x = copy(predict(wg, noise));
    fake_y = Array{UInt8}(zeros(size(y)))
    
    g = lossgradient(wd, hcat(x, fake_x), hcat(y, fake_y))
    
    update!(wd, g, optimd)
    return wd, fake_x
end
# Out:
# traind (generic function with 1 method)

# %%
function traing(wd, wg, fake_x, y, optimg)
    output = predict(wd, fake_x)
    g = lossgradient(wg, output, y)
    update!(wg, g, optimg)
    return wg
end
# Out:
# traing (generic function with 1 method)

# %%
nsamples2plot = 100
srand(1)
wg = generator_init(2);
wd = discriminator_init(2);
optimg = optimizers(wg, Adam;  lr=0.001)
optimd = optimizers(wd, Adam;  lr=0.005)
Fake_x = []
for epoch = 1:10
    
    push!(Fake_x, predict(wg, Array{Float32}(randn(2, nsamples2plot))));
    for (x, y) in dtrn
        wd, fake_x = traind(wd, wg, x, y, optimd)        
        wg = traing(wd, wg, fake_x, y, optimg)
    end  
    
    if epoch % 2 == 0
        scatter(xtrn[1, :], xtrn[2, :], label=:true_data)
        display(scatter!(Fake_x[epoch][1, :], Fake_x[epoch][2, :],  label=:synthetic_data, size=(400,300)))
    end
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="400" height="300" viewBox="0 0 400 300">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="400" height="300"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8100)" points="
# 0,300 400,300 400,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="80" y="0" width="281" height="281"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8100)" points="
# 29.2591,274.759 380.315,274.759 380.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="352" height="264"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.5435,270.814 60.5435,15.7552
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   111.746,270.814 111.746,15.7552
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   162.949,270.814 162.949,15.7552
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   214.152,270.814 214.152,15.7552
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   265.355,270.814 265.355,15.7552
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   316.558,270.814 316.558,15.7552
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   367.761,270.814 367.761,15.7552
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   34.525,236.055 375.049,236.055
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   34.525,178.497 375.049,178.497
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   34.525,120.939 375.049,120.939
#   "/>
# <polyline clip-path="url(#clip8102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   34.525,63.3802 375.049,63.3802
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,274.759 380.315,274.759
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,274.759 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.5435,274.759 60.5435,270.814
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   111.746,274.759 111.746,270.814
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   162.949,274.759 162.949,270.814
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   214.152,274.759 214.152,270.814
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   265.355,274.759 265.355,270.814
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   316.558,274.759 316.558,270.814
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   367.761,274.759 367.761,270.814
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,236.055 34.525,236.055
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,178.497 34.525,178.497
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,120.939 34.525,120.939
#   "/>
# <polyline clip-path="url(#clip8100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,63.3802 34.525,63.3802
#   "/>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 60.5435, 287.559)" x="60.5435" y="287.559">-2</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 111.746, 287.559)" x="111.746" y="287.559">-1</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 162.949, 287.559)" x="162.949" y="287.559">0</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 214.152, 287.559)" x="214.152" y="287.559">1</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 265.355, 287.559)" x="265.355" y="287.559">2</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 316.558, 287.559)" x="316.558" y="287.559">3</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 367.761, 287.559)" x="367.761" y="287.559">4</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 25.2591, 240.555)" x="25.2591" y="240.555">-3</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 25.2591, 182.997)" x="25.2591" y="182.997">0</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 25.2591, 125.439)" x="25.2591" y="125.439">3</text>
# </g>
# <g clip-path="url(#clip8100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 25.2591, 67.8802)" x="25.2591" y="67.8802">6</text>
# </g>
# <circle clip-path="url(#clip8102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="274.224" cy="101.258" r="4"/>
# <circle clip-path="url(#clip8102)" style="fill:#009af9; stroke:none; fill-opacity:1" cx