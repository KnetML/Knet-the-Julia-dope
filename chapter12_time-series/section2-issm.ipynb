# %% [markdown]
# # Julia Things

# %% [markdown]
# ### Environment
#
# First things first. Let us set up the environment with the requried packages for this notebook. We will also set the desired context (e.g. `KnetArray` for gpu), the number of epochs (`nepochs`), and the variable `fast`. This variable is used to skip checking the accuracy at every epoch.

# %%
for p in ("Knet", "Plots", "DataFrames")
    Pkg.installed(p) == nothing && Pkg.add(p)
end

using Knet, Plots, DataFrames, DSP
gr()

Knet.gpu(0); # set the desired GPU to use
atype   = Array{Float64}; # atype = KnetArray{Float32} for gpu usage, Array{Float32} for cpu. 
nepochs = 10
fast    = false

println("OS: ", Sys.KERNEL)
println("Julia: ", VERSION)
println("Knet: ", Pkg.installed("Knet"))
println("GPU: ", readstring(`nvidia-smi --query-gpu=name --format=csv,noheader`))
# Out:
# OS: Linux
# Julia: 0.6.0
# Knet: 0.8.5+
# GPU: NVS 310
# TITAN X (Pascal)

# %% [markdown]
# ### New Stuff
#
# In this notebook we introduce the following Julia/Knet packages and functions:
#
# * Julia's [DSP](https://github.com/JuliaDSP/DSP.jl) package: Filter design, periodograms, window functions, and other digital signal processing functionality.
# * DSP's functions `Bandpass`, `Butterworth`, `digitalfilter`, and `filt`.

# %% [markdown]
# # Exponential Smoothing and Innovation State Space Model (ISSM)
#
# In this notebook we will illustrate the implementation of filtering in innovation state space model (ISSM, for short) using Knet. Let us first briefy reivew the basic concepts.
#
#
# Time series forecasting is a central problem occuring in many applications from optimal inventory management, staff scheduling to topology planning.
# Given a sequence of measurements $z_1, \ldots, z_T$ observed over time, the problem here is to predict future values of the time series $z_{T+1}, \ldots, z_{T+\tau}$, where $\tau$ is referred as the *time horizon*.
#
# Exponential smoothing (ETS, which stands for *Error, Trend, and Seasonality*) is a family of very successful forecasting methods which are based on the key property that forecasts are weighted combinations of past observations ([Hyndman et. al, 2008](http://www.exponentialsmoothing.net/home)).
#
# For example, in simple exponential smoothing, the foreacast $\hat{z}_{T+1}$ for time step $T+1$ is written as ([Hyndman, Athanasopoulos, 2012](https://www.otexts.org/fpp/7/1))
#
# $$ \hat{z}_{T+1} = \hat{z}_T + \alpha (z_T - \hat{z}_T) = \alpha\cdot z_T + (1 - \alpha)\cdot \hat{z}_T, $$
#
# In words, the next step forecast is a convex combination of the most recent obseravtion and forecast. Expanding the above equation, it is clear that the forecast is given by the exponentially weighted average of past observations,
#
# $$ \hat{z}_{T+1} = \alpha z_T + \alpha(1-\alpha) z_{T-1} + \alpha(1-\alpha)^2 z_{T-2}+ \cdots. $$
#
# Here $\alpha > 0$ is a smoothing parameter that controls the weight given to each observation.
# Note that the recent observations are given more weight than the older observations.
# In fact the weight given to the past observation descreases exponentially as it gets older and hence the name **exponential smoothing**.
#
# General exponential smoothing methods consider the extensions of simple ETS to include time series patterns such as (linear) trend, various periodic seasonal effects. All ETS methods falls under the category of forecasting methods as the predictions are point forecasts (a single value is predicted for each future time step).
# On the other hand a statistical model describes the underlying data generation process and has an advantage that it can produce an entire probability distribuiton for each of the future time steps.
# Innovation state space model (ISSM) is an example of such models with considerable flexibility in respresnting commonly occurring time series patterns and underlie the exponential smoothing methods.
#
# The idea behind ISSMs is to maintain a latent state vector $l_{t}$ with recent information about level, trend, and seasonality factors.
# The state vector $l_t$ evolves over time adding small *innvoation* (i.e., the Gaussian noise) at each time step.
# The observations are then a linear combination of the components of the current state.
#
# Mathematically, ISSM is specified by two equations
#
# * The state transition equation is given by
#
# $$l_{t} = F_t l_{t-1} + g_{t}\epsilon_t,\quad \epsilon_t\sim \mathcal{N}(0,1).$$
#
# Note that the innovation strength is controlled by $g_t$, i.e., $g_t\epsilon_t \sim \mathcal{N}(0, g_t^2)$.
#
# * The observation equation is given by
#
# $$z_t = a_{t}^{\top}l_{t-1} + b_t + \nu_t, \quad \nu_t \sim \mathcal{N}(0, \sigma_t^2)$$
#
# Note that here we allow for an additional term $b_t$ which can model any determinstic component (exogenous variables).
#
# This describes a fairy generic model allowing the user to encode specific time series patterns using the coefficients $F$, $a_t$ and thus are problem dependent. The innovation vector $g_t$ comes in terms of parameters to be learned (the innovation strengths). Moreover, the initial state $l_0$ has to be specified.
# We do so by specifying a Gaussian prior distribution $P(l_0)$, whose parameters (means, standard deviation) are learned from data as well.
#
# The parameters of the ISSM are typically learned using the maximum likelihood principle.
# This requires the computation of the log-likelihood of the given observations i.e., computing the probability of the data under the model, $P(z_1, \ldots, z_T)$. Fortunately, in the previous notebook, we have learned how to compute the log-likelihood as a byproduct of LDS filtering problem.

# %% [markdown]
# # Filtering
#
# We remark that ISSM is a special case of linear dynamical system except that the coefficients are allowed to change over time. The filtering equations for ISSM can readily be obtained from the general derivation described in LDS.
#
#
# Note the change in the notation in the following equations for filtered mean ($\mu_t$) and filtered variance ($S_t$) because of the conflict of notation for the ISSM coefficient $F$. Also note that the deterministic part $b_t$ needs to be subtracted from the observations $[z_t]$.
#
# $$\mu_h = F_t \mu_{t-1} \quad \quad \quad \mu_v = a_t^{\top}\mu_h$$
#
# $$\Sigma_{hh} = F_t S_{t-1}F_t^T + g_t g_t^T \quad \quad \quad \sigma^2_{v} = a_t^T\Sigma_{hh}a_t + \sigma_t^2$$
#
# $$K_t = \frac{1} {\sigma^2_{v}} \Sigma_{hh}a_t $$
#
# $$\mu_t = \mu_h + K(z_t - b_t -\mu_v) \quad \quad \quad S_t = (I - K_t a_t^T)\Sigma_{hh}(I-K_t a_t^T)^T +  \sigma^2_t K_tK_t^T$$

# %%
function ISSM_filter(z, b, F, a, g, sigma, m_prior, S_prior)
    
    H = size(F, 1);
    T = size(z, 1)
    
    eye_h = eye(Float64, H)
    
    mu_seq    = []
    S_seq     = []
    log_p_seq = []
    mu_t      = 0
    S_t       = 0
    for t = 1:T
        
        if t == 1
            # At the first time step, use the prior
            mu_h = m_prior
            S_hh = S_prior
        else
            # Otherwise compute using update eqns.
            F_t = F[:, :, t];
            g_t = reshape(g[:, t], H, 1);
            mu_h = F_t * mu_t;
            S_hh = F_t * (S_t * F_t') + g_t * g_t';
        end
        
        
        a_t  = reshape(a[:, t], H, 1)
        mu_v = mu_h' * a_t;
        
        # Compute the Kalman gain (vector)
        S_hh_x_a_t = S_hh * a_t;

        sigma_t = sigma[t]
        S_vv    = a_t' * S_hh_x_a_t + sigma_t .^ 2

        kalman_gain = S_hh_x_a_t ./ S_vv

        # Compute the error (delta)
        delta = z[t] - b[t] - mu_v
        # Filtered estimates
        mu_t = mu_h .+ kalman_gain * delta;

        # Joseph's symmetrized update for covariance:
        
        ImKa = eye_h .- kalman_gain * a_t';


        S_t = (ImKa * S_hh) * ImKa' + (kalman_gain * kalman_gain') .* sigma_t .^ 2

        # likelihood term
        log_p = -0.5 * (delta * delta) ./ S_vv + log(2.0 + pi) + log.(S_vv)


        push!(mu_seq, mu_t)
        push!(S_seq, S_t)
        push!(log_p_seq, log_p)
    end
    
    return mu_seq, S_seq, log_p_seq

end
# Out:
# ISSM_filter (generic function with 1 method)

# %% [markdown]
# ## Data
#
# We will use the [beer shipment dataset](https://datamarket.com/data/set/2325/four-weekly-totals-of-beer-shipments#!ds=2325&display=line) to illustrate two specific instances of ISSM models.

# %%
data = readtable("../datasets/fourweekly-totals-of-beer-shipme.csv");

# %%
z  = Array{Float64}(data[:, 2])
ts = (z - mean(z)) / std(z);

# %%
plot(data[:, 1], data[:, 2])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 48.6962,375.813 580.315,375.813 580.315,11.811 48.6962,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="11" width="533" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.353 48.6962,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   91.2257,370.353 91.2257,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   123.123,370.353 123.123,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   165.652,370.353 165.652,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   197.549,370.353 197.549,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   240.079,370.353 240.079,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   271.976,370.353 271.976,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.353 314.506,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   357.035,370.353 357.035,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   388.932,370.353 388.932,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   431.462,370.353 431.462,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   463.359,370.353 463.359,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   505.888,370.353 505.888,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   537.785,370.353 537.785,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,367.003 572.341,367.003
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,257.423 572.341,257.423
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,147.843 572.341,147.843
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,38.2636 572.341,38.2636
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,11.811
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   91.2257,375.813 91.2257,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   123.123,375.813 123.123,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   165.652,375.813 165.652,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   197.549,375.813 197.549,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   240.079,375.813 240.079,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   271.976,375.813 271.976,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   357.035,375.813 357.035,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   388.932,375.813 388.932,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   431.462,375.813 431.462,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   463.359,375.813 463.359,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   505.888,375.813 505.888,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   537.785,375.813 537.785,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,367.003 56.6705,367.003
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,257.423 56.6705,257.423
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,147.843 56.6705,147.843
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,38.2636 56.6705,38.2636
#   "/>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">1970-W06</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 91.2257, 389.613)" x="91.2257" y="389.613">1970-W22</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 123.123, 389.613)" x="123.123" y="389.613">1970-W34</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 165.652, 389.613)" x="165.652" y="389.613">1970-W50</tex

# %% [markdown]
# ## Level ISSM
#
# The simplest possible ISSM maintains a level component only. Abusing the notation and let $l_t$ denote *level*, the level ISSM can be written as
#
# $$
# \begin{split}
# l_t = \delta l_{t-1} + \alpha \epsilon_t.
# \end{split}
# $$
#
# Or in ISSM terminology,
# $$
#   a_{t} = [ \delta ],\quad F_{t} = [ \delta ],\quad g_{t} = [ \alpha ],\quad \alpha>0.
# $$
#
# The level $l_t \in \mathbb{R}$ evolves over time by adding a random innovation $\alpha \epsilon_t \sim \mathcal{N}(0,\alpha^2)$ to the previous level, so that $\alpha$ specifies the amount of level drift over time. At time $t$, the previous level $l_{t-1}$ is used in the prediction $z_t$ and then the level is updated.
# The damping factor $\delta \in (0, 1]$ allows the ``damping'' of the level.
# The initial state prior $P(l_0)$ is given by $l_0 \sim N(\mu_0, \sigma_0^2)$. For Level-ISSM, we learn the parameters $\alpha>0$, $\mu_0$, $\sigma_0>0$.

# %% [markdown]
# Here we will fix the parameters for the illustration of filtering.
# Learning of the parameters will be discussed in another notebook.

# %%
function initmodel(ts)

    latent_dim = 1;
    T          = length(ts);

    # Set the coefficients of the ISSM
    delta      = Float64(1.0)
    F          = delta * ones(Float64, 1, 1, T);
    a          = delta * ones(Float64, 1, T);

    # Set the parameters of the ISSM
    alpha      = Float64(0.5);
    g          = alpha * ones(Float64, 1, T);

    m_prior    = zeros(Float64, latent_dim, 1)
    S_prior    = zeros(Float64, latent_dim, latent_dim)
    sigma      = 0.5 * ones(Float64, T, 1)
    b          = zeros(Float64, T, 1)
    z          = copy(ts);

    return z, b, F, a, g, sigma, m_prior, S_prior
end
# Out:
# initmodel (generic function with 1 method)

# %%
function ISSM_filter(z, b, F, a, g, sigma, m_prior, S_prior)
    
    H = size(F, 1);
    T = size(z, 1)
    
    eye_h = eye(Float64, H)
    
    mu_seq    = []
    S_seq     = []
    log_p_seq = []
    mu_t      = 0
    S_t       = 0
    for t = 1:T
        
        if t == 1
            # At the first time step, use the prior
            mu_h = m_prior
            S_hh = S_prior
        else
            # Otherwise compute using update eqns.
            F_t = F[:, :, t];
            g_t = reshape(g[:, t], H, 1);
            mu_h = F_t * mu_t;
            S_hh = F_t * (S_t * F_t') + g_t * g_t';
        end
        
        
        a_t  = reshape(a[:, t], H, 1)
        mu_v = mu_h' * a_t;
        
        # Compute the Kalman gain (vector)
        S_hh_x_a_t = S_hh * a_t;

        sigma_t = sigma[t]
        S_vv    = a_t' * S_hh_x_a_t + sigma_t .^ 2

        kalman_gain = S_hh_x_a_t ./ S_vv

        # Compute the error (delta)
        delta = z[t] - b[t] - mu_v
        # Filtered estimates
        mu_t = mu_h + kalman_gain * delta;

        # Joseph's symmetrized update for covariance:
        
        ImKa = eye_h .- kalman_gain * a_t';


        S_t = (ImKa * S_hh) * ImKa' + (kalman_gain * kalman_gain') .* sigma_t .^ 2

        # likelihood term
        log_p = -0.5 * (delta * delta) ./ S_vv + log(2.0 + pi) + log.(S_vv)


        push!(mu_seq, mu_t)
        push!(S_seq, S_t)
        push!(log_p_seq, log_p)
    end
    
    return mu_seq, S_seq, log_p_seq

end
# Out:
# ISSM_filter (generic function with 1 method)

# %%
z, b, F, a, g, sigma, m_prior, S_prior = initmodel(ts)
mu_seq, S_seq, _ = ISSM_filter(z, b, F, a, g, sigma, m_prior, S_prior);

# %% [markdown]
# ### Calculate the filtered mean and variance of observations
#
#
# Given $p(l_{t-1}|z_{1:t})=\mathcal{N}(\mu_t, S_t)$, we can compute the distribution of the reconstructed observations
#
# $$
# p(\widehat{z_t}) = \mathcal{N}(a_t^T\mu_t, a_t^TS_ta_t + \sigma_t^2).
# $$

# %%
function reconstruct(a, H, mu_seq, S_seq)
    
    v_filtered_mean = [(reshape(a[:,t], 1, H)*mu_t)[1] for (t,mu_t) in zip(1:length(mu_seq),mu_seq)];
    v_filtered_std  = [(reshape(a[:,t], 1, H)S_t*a[:,t]+ sigma[t].^2)[1] for (t,S_t) in zip(1:length(S_seq),S_seq)];
    v_filtered_std  = sqrt.(v_filtered_std);

    return v_filtered_mean, v_filtered_std

end
# Out:
# reconstruct (generic function with 3 methods)

# %%
v_filtered_mean, v_filtered_std = reconstruct(a, size(F, 1), mu_seq, S_seq);

# %% [markdown]
# ### Forecast
#
# One advantage of the ISSM model is that one can obtain the complete probability distribution for each of the future time steps:
#
# $$
# p(\widehat{z_{T+t}}) = \mathcal{N}(a_{T+t}^T\mu_{T+t}, a_{T+t}^TS_{T+t}a_{T+t} + \sigma_{T+t}^2),\quad t > 0 \\
# p(l_{T+t}) = \mathcal{N}(F\mu_{T+t-1}, FS_{T+t-1}F^T + g_{T+t} g_{T+t}^T)
# $$

# %%
function forecast(mu_last_state, S_last_state, F, a, g, sigma; horizon=13)

    forecasts_mean = []
    forecasts_std  = []
    H = size(F, 1);
    for t = 1:horizon
        a_t  = reshape(a[:, t], 1, H)
        forecast_mean = a_t * mu_last_state
        
        forecast_std  = a_t * S_last_state * a_t' + sigma[t] .^ 2
        push!(forecasts_mean, forecast_mean[1])
        push!(forecasts_std, forecast_std[1])
        mu_last_state = F[:, :, t] * mu_last_state
        S_last_state  = F[:, :, t] * S_last_state * F[:, :, t]'
    end
    
    return forecasts_mean, forecasts_std
    
end
# Out:
# forecast (generic function with 2 methods)

# %%
# Let us use the same cofficients (constant over time) for the future as well
forecasts_mean, forecasts_std = forecast(mu_seq[end], 
                                         S_seq[end], 
                                          F, a, g, sigma; horizon=13);

# %%
function plot_reconstruction_forecasts(ts, v_filtered_mean, v_filtered_std, forecasts_mean, forecasts_std)

    T = length(v_filtered_mean);
    plot(1:T, v_filtered_mean, grid=false, ribbon=v_filtered_std,fillalpha=.5, color=:blue, label=:_, legend=:bottomleft)
    plot!(ts, color=:red, label=:data)
    plot!(v_filtered_mean, color=:blue, label=:reconstruction)
    plot!(T:T+length(forecasts_mean) - 1, forecasts_mean, grid=false, ribbon=forecasts_std,fillalpha=.5, color=:green, label=:forecasts)

end
# Out:
# plot_reconstruction_forecasts (generic function with 1 method)

# %%
plot_reconstruction_forecasts(ts, v_filtered_mean, v_filtered_std, forecasts_mean, forecasts_std)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0900)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   109.251,375.813 109.251,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   198.131,375.813 198.131,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   287.011,375.813 287.011,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   375.891,375.813 375.891,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   464.771,375.813 464.771,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   553.651,375.813 553.651,370.353
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,365.435 37.525,365.435
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,286.666 37.525,286.666
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,207.897 37.525,207.897
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,129.127 37.525,129.127
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,50.3583 37.525,50.3583
#   "/>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 109.251, 389.613)" x="109.251" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 198.131, 389.613)" x="198.131" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 287.011, 389.613)" x="287.011" y="389.613">30</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 375.891, 389.613)" x="375.891" y="389.613">40</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 464.771, 389.613)" x="464.771" y="389.613">50</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 553.651, 389.613)" x="553.651" y="389.613">60</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 369.935)" x="23.2591" y="369.935">-2</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 291.166)" x="23.2591" y="291.166">-1</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 212.397)" x="23.2591" y="212.397">0</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 133.627)" x="23.2591" y="133.627">1</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 54.8583)" x="23.2591" y="54.8583">2</text>
# </g>
# <polygon clip-path="url(#clip0902)" points="
# 29.2591,247.281 38.1471,313.767 38.1471,217.295 29.2591,168.512
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 38.1471,313.767 47.0351,332.448 47.0351,232.812 38.1471,217.295
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 47.0351,332.448 55.9231,308.165 55.9231,208.051 47.0351,232.812
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 55.9231,308.165 64.8111,279.141 64.8111,178.957 55.9231,208.051
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 64.8111,279.141 73.6991,237.577 73.6991,137.383 64.8111,178.957
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 73.6991,237.577 82.5871,207.615 82.5871,107.419 73.6991,137.383
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 82.5871,207.615 91.4751,225.06 91.4751,124.864 82.5871,107.419
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 91.4751,225.06 100.363,275.684 100.363,175.488 91.4751,124.864
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 100.363,275.684 109.251,315.299 109.251,215.103 100.363,175.488
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 109.251,315.299 118.139,342.892 118.139,242.696 109.251,215.103
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 118.139,342.892 127.027,355.203 127.027,255.007 118.139,242.696
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 127.027,355.203 135.915,375.813 135.915,275.617 127.027,255.007
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 135.915,375.813 144.803,363.407 144.803,263.211 135.915,275.617
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 144.803,363.407 153.691,338.836 153.691,238.64 144.803,263.211
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 153.691,338.836 162.579,320.991 162.579,220.795 153.691,238.64
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 162.579,320.991 171.467,277.402 171.467,177.206 162.579,220.795
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 171.467,277.402 180.355,228.502 180.355,128.306 171.467,177.206
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip0902)" points="
# 180.355,

# %% [markdown]
# ### Level Trend ISSM
#
# We can model a piecewise linear random process by using a two-dimensional latent state $l_{t}\in \mathbb{R}^2$, where one dimension represents the level (again with a slight abusing of notation, $l$) and the other represents the trend (slope) $b$.
#
# $$
# \begin{split}
#   l_t &= \delta l_{t - 1} + \gamma b_{t - 1} + \alpha\cdot\epsilon_t\\
#   b_t &= \gamma b_{t - 1} + \beta\cdot\epsilon_t
#   \end{split}
# $$
#
#
# In ISSM framework, such a (Damped) LevelTrend-ISSM is given by
#
# $$
#   a_{t} = \left[\begin{array}{c}
#     \delta \\
#     \gamma
#   \end{array}\right], \quad F_{t} = \left[\begin{array}{cc}
#     \delta & \gamma \\
#     0 & \gamma
#   \end{array}\right], \quad g_{t} = \left[\begin{array}{c}
#     \alpha \\
#     \beta
#   \end{array}\right],
# $$
#
# where $\alpha>0$, $\beta>0$ and the damping factors $\delta, \gamma \in (0, 1]$.
# Both the level and slope components evolve over time by adding innovations $\alpha \epsilon_t$ and $\beta \epsilon_t$ respectively, so that $\beta>0$ is the innovation strength for the slope. The level at time $t$ is the sum of level at $t-1$ and slope at $t-1$ (linear prediction) modulo the damping factors for level $\delta$ and growth $\gamma$.

# %%
function initmodel2(ts)
    latent_dim = 2
    T          = length(ts)

    # Set the coefficients of the ISSM
    damp_fact   = 1.0
    damp_growth = 1.0

    # Set the parameters of the ISSM
    alpha      = 0.5 
    beta       = 0.1 
    g_t        = [alpha, beta]
    g = reshape(repeat(g_t; inner=T), latent_dim, T);


    F_t = reshape([damp_fact, damp_growth, 0, damp_growth], latent_dim, latent_dim);
    a_t = [damp_fact, damp_growth];

    #F = reshape(repeat(F_t, outer=(T, 1), inner=(1,1)), latent_dim, latent_dim, T);
    F = Array{Float64}(2, 2, T)
    F[1, 1, :] = damp_fact*ones(1, T)
    F[1, 2, :] = damp_growth*ones(1, T)
    F[2, 1, :] = zeros(1, T)
    F[2, 2, :] = damp_growth*ones(1, T);

    a = reshape(repeat(a_t, inner=T), latent_dim, T);


    m_prior    = zeros(latent_dim, 1)
    S_prior    = zeros(latent_dim, latent_dim)
    sigma      = 0.5 * ones(T, 1)
    b          = zeros(T, 1)
    z          = copy(ts);
    
    return z, b, F, a, g, sigma, m_prior, S_prior
    
end
# Out:
# initmodel2 (generic function with 1 method)

# %%
mu_seq, S_seq, _ = ISSM_filter(z, b, F, a, g, sigma, m_prior, S_prior);

# %%
# Let us use the same cofficients (constant over time) for the future as well
forecasts_mean, forecasts_std = forecast(mu_seq[end], 
                                         S_seq[end], 
                                          F, a, g, sigma; horizon=13);

# %%
reconst_mean, reconst_std = reconstruct(a, mu_seq, S_seq);

# %% [markdown]
# ## Plot the reconstruction as well as the forecasts

# %%
plot_reconstruction_forecasts(ts, v_filtered_mean, v_filtered_std, forecasts_mean, forecasts_std)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 29.2591,375.813 580.315,375.813 580.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,375.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   109.251,375.813 109.251,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   198.131,375.813 198.131,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   287.011,375.813 287.011,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   375.891,375.813 375.891,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   464.771,375.813 464.771,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   553.651,375.813 553.651,370.353
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,352.697 37.525,352.697
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,272.388 37.525,272.388
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,192.079 37.525,192.079
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,111.77 37.525,111.77
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,31.4614 37.525,31.4614
#   "/>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 109.251, 389.613)" x="109.251" y="389.613">10</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 198.131, 389.613)" x="198.131" y="389.613">20</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 287.011, 389.613)" x="287.011" y="389.613">30</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 375.891, 389.613)" x="375.891" y="389.613">40</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 464.771, 389.613)" x="464.771" y="389.613">50</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 553.651, 389.613)" x="553.651" y="389.613">60</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 357.197)" x="23.2591" y="357.197">-6</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 276.888)" x="23.2591" y="276.888">-4</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 196.579)" x="23.2591" y="196.579">-2</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 116.27)" x="23.2591" y="116.27">0</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 35.9614)" x="23.2591" y="35.9614">2</text>
# </g>
# <polygon clip-path="url(#clip1102)" points="
# 29.2591,131.847 38.1471,165.74 38.1471,116.561 29.2591,91.693
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 38.1471,165.74 47.0351,175.263 47.0351,124.472 38.1471,116.561
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 47.0351,175.263 55.9231,162.884 55.9231,111.849 47.0351,124.472
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 55.9231,162.884 64.8111,148.089 64.8111,97.0177 55.9231,111.849
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 64.8111,148.089 73.6991,126.9 73.6991,75.824 64.8111,97.0177
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 73.6991,126.9 82.5871,111.627 82.5871,60.5496 73.6991,75.824
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 82.5871,111.627 91.4751,120.52 91.4751,69.4426 82.5871,60.5496
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 91.4751,120.52 100.363,146.326 100.363,95.2492 91.4751,69.4426
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 100.363,146.326 109.251,166.521 109.251,115.444 100.363,95.2492
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 109.251,166.521 118.139,180.587 118.139,129.51 109.251,115.444
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 118.139,180.587 127.027,186.863 127.027,135.786 118.139,129.51
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 127.027,186.863 135.915,197.37 135.915,146.292 127.027,135.786
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 135.915,197.37 144.803,191.045 144.803,139.968 135.915,146.292
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 144.803,191.045 153.691,178.519 153.691,127.442 144.803,139.968
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 153.691,178.519 162.579,169.423 162.579,118.345 153.691,127.442
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 162.579,169.423 171.467,147.202 171.467,96.1248 162.579,118.345
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 171.467,147.202 180.355,122.274 180.355,71.1971 171.467,96.1248
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip1102)" points="
# 180.355,122.274 189.24

# %% [markdown]
# # Cardiac ECG Data
#
# Let us try a different dataset. In this example we will use electrocardiogram (ECG) data from the [physiobank dataset](https://www.physionet.org/physiobank/annotations.shtml):

# %%
data         = readtable("../datasets/ecg_data/MIT-BIH-arrhythmia-database/100.csv");
time_stamps  = readtable("../datasets/ecg_data/MIT-BIH-arrhythmia-database/100_ann.csv");
label_stamps = readtable("../datasets/ecg_data/MIT-BIH-arrhythmia-database/100_anntype.csv");

# %% [markdown]
# Let us extract long and short samples from this dataset:

# %%
S = 256 * 1;
L = 256 * 10;

ECG_short = (data[1:S, 2] - mean(data[1:S, 2])) / std(data[1:S, 2]);
ECG_long  = (data[1:L, 2] - mean(data[1:L, 2])) / std(data[1:L, 2]);

# %% [markdown]
# It should be no surprise that noise can be a problem in ECG analysis. Fortunately, the signal-to-noise ratio is usually quite good in a person at rest. In an active person, however, there can be substantial low frequency (< 15 Hz) noise due to electrode motion, and high frequency (> 15 Hz) noise due to skeletal muscle activity. In addition, there is the possibility of noise at 60 Hz (or 50 Hz in some countries) and its harmonics due to power-line noise. We will filter the ECG data, sampled at 350 Hz, with a 4th order Butterworth bandpass filter between 5 and 30 Hz:

# %%
responsetype = Bandpass(5, 30; fs=350)
designmethod = Butterworth(4)
ts_long = filt(digitalfilter(responsetype, designmethod), ECG_long);
ts      = filt(digitalfilter(responsetype, designmethod), ECG_short);

# %% [markdown]
# Let us visualize the data:

# %%
l   = @layout([a{0.2h}; b])
hms = [[ts], [ts]]
plot([ts_long, ts], layout=l, legend=false, xlabel=:time, ylabel=:voltage)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8300)" points="
# 45.0072,71.1128 580.315,71.1128 580.315,11.811 45.0072,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="11" width="536" height="60"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.391,70.2233 149.391,12.7005
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   253.984,70.2233 253.984,12.7005
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   358.577,70.2233 358.577,12.7005
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   463.171,70.2233 463.171,12.7005
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   567.764,70.2233 567.764,12.7005
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,59.9921 572.285,59.9921
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,46.0512 572.285,46.0512
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,32.1104 572.285,32.1104
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,18.1695 572.285,18.1695
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,71.1128 580.315,71.1128
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,71.1128 45.0072,11.811
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.391,71.1128 149.391,70.2233
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   253.984,71.1128 253.984,70.2233
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   358.577,71.1128 358.577,70.2233
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   463.171,71.1128 463.171,70.2233
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   567.764,71.1128 567.764,70.2233
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,59.9921 53.0368,59.9921
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,46.0512 53.0368,46.0512
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,32.1104 53.0368,32.1104
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,18.1695 53.0368,18.1695
#   "/>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.391, 84.9128)" x="149.391" y="84.9128">500</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 253.984, 84.9128)" x="253.984" y="84.9128">1000</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 358.577, 84.9128)" x="358.577" y="84.9128">1500</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 463.171, 84.9128)" x="463.171" y="84.9128">2000</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 567.764, 84.9128)" x="567.764" y="84.9128">2500</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 64.4921)" x="39.0072" y="64.4921">-4</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 50.5512)" x="39.0072" y="50.5512">-2</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 36.6104)" x="39.0072" y="36.6104">0</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 22.6695)" x="39.0072" y="22.6695">2</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 312.661, 108.647)" x="312.661" y="108.647">time</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 41.4619)" x="14.4" y="41.4619">voltage</text>
# </g>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,32.0994 45.2164,32.0261
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.2164,32.0261 45.4255,31.7972
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.4255,31.7972 45.6347,31.3429
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.6347,31.3429 45.8439,30.6897
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.8439,30.6897 46.0531,29.9686
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.0531,29.9686 46.2623,29.3658
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.2623,29.3658 46.4715,29.0542
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.4715,29.0542 46.6807,29.1355
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.6807,29.1355 46.8899,29.6163
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; str

# %%
hms = []
for k in [2, 5, 6, 7]
    S = 256 * k;
    ECG_short = (data[1 + shift:S, 2] - mean(data[1 + shift:S, 2])) / std(data[1 + shift:S, 2]);

    responsetype = Bandpass(5, 30; fs=350)
    designmethod = Butterworth(4)
    ts      = filt(digitalfilter(responsetype, designmethod), ECG_short);

    z, b, F, a, g, sigma, m_prior, S_prior = initmodel2(ts)
    mu_seq, S_seq, _ = ISSM_filter(z, b, F, a, g, sigma, m_prior, S_prior);
    v_filtered_mean, v_filtered_std = reconstruct(a, size(F, 1), mu_seq, S_seq);
    forecasts_mean, forecasts_std = forecast(mu_seq[end], S_seq[end], F, a, g, sigma; horizon=20);

    N = 300
    push!(hms, plot_reconstruction_forecasts(ts[end-N: end], 
              v_filtered_mean[end-N: end], v_filtered_std[end-N: end],
              forecasts_mean, forecasts_std))
end

# %%
l   = @layout([a b; c d])
#hms = [[ts], [ts]]
plot(hms..., layout=l, legend=false)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8500)" points="
# 29.2591,175.813 280.315,175.813 280.315,11.811 29.2591,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="29" y="11" width="252" height="165"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,175.813 280.315,175.813
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,175.813 29.2591,11.811
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   67.8226,175.813 67.8226,173.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   107.173,175.813 107.173,173.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   146.523,175.813 146.523,173.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   185.874,175.813 185.874,173.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.224,175.813 225.224,173.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   264.575,175.813 264.575,173.353
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,165.727 33.025,165.727
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,143.314 33.025,143.314
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,120.901 33.025,120.901
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,98.4871 33.025,98.4871
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,76.0737 33.025,76.0737
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,53.6602 33.025,53.6602
#   "/>
# <polyline clip-path="url(#clip8500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.2591,31.2468 33.025,31.2468
#   "/>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 67.8226, 189.613)" x="67.8226" y="189.613">50</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 107.173, 189.613)" x="107.173" y="189.613">100</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 146.523, 189.613)" x="146.523" y="189.613">150</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 185.874, 189.613)" x="185.874" y="189.613">200</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.224, 189.613)" x="225.224" y="189.613">250</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 264.575, 189.613)" x="264.575" y="189.613">300</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 170.227)" x="23.2591" y="170.227">-6</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 147.814)" x="23.2591" y="147.814">-4</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 125.401)" x="23.2591" y="125.401">-2</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 102.987)" x="23.2591" y="102.987">0</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 80.5737)" x="23.2591" y="80.5737">2</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 58.1602)" x="23.2591" y="58.1602">4</text>
# </g>
# <g clip-path="url(#clip8500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.2591, 35.7468)" x="23.2591" y="35.7468">6</text>
# </g>
# <polygon clip-path="url(#clip8502)" points="
# 29.2591,108.052 30.0462,108.236 30.0462,92.9762 29.2591,92.7919
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 30.0462,108.236 30.8332,108.374 30.8332,93.1147 30.0462,92.9762
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 30.8332,108.374 31.6202,108.447 31.6202,93.1869 30.8332,93.1147
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 31.6202,108.447 32.4072,108.441 32.4072,93.1808 31.6202,93.1869
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 32.4072,108.441 33.1942,108.355 33.1942,93.0949 32.4072,93.1808
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 33.1942,108.355 33.9812,108.197 33.9812,92.9376 33.1942,93.0949
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 33.9812,108.197 34.7682,107.987 34.7682,92.7275 33.9812,92.9376
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 34.7682,107.987 35.5552,107.751 35.5552,92.4909 34.7682,92.7275
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 35.5552,107.751 36.3422,107.512 36.3422,92.252 35.5552,92.4909
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 36.3422,107.512 37.1292,107.285 37.1292,92.0255 36.3422,92.252
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 37.1292,107.285 37.9162,107.075 37.9162,91.8154 37.1292,92.0255
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon clip-path="url(#clip8502)" points="
# 37.9162,107.075 38.7032,106.877 38.7032,91.6169 37.9162,91.8154
#   " fill="#0000ff" fill-opacity="0.5"/>
# <polygon
